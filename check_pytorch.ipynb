# %%
import torch
import time

# %%
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("✅ STATUS: M5 GPU (MPS) Activated.")
else:
    device = torch.device("cpu")
    print("❌ STATUS: Running on CPU (Slow). Check your installation.")
# Out:
# ✅ STATUS: M5 GPU (MPS) Activated.
